# %% [markdown]
# <a href="https://colab.research.google.com/github/wavaronr/MetodosNumericos/blob/main/Copia_de_G73_WilmerVaron_Ej2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso**: *Metodos Numericos*
#
# **Tarea:** *Tarea 3 - Cálculo y E.D.O Numéricas*
#
# **Presentado por:** *Wilmer Alexander Varon Rodriguez*
#
# **Grupo:** *73*
#
# **Codigo:** *1013601371*
#
# **Presentado a:** *Henock Venegas*
#
# **Universidad Nacional Abierta y a Distancia – UNAD**
# Fecha: 14 de Mayo de 2023
# ---

# %% [markdown]
# _________________________________________
# _________________________________
# # **Presentación del ejercicio en una celda markdown.**
#
# Ejercicio 2: Integración numérica
#
# Descripción del ejercicio:
# Dadas las siguientes integrales,
#
# $\int_0^{\mathrm\pi/2}\frac1{1+sen(x)}\operatorname dx$
#
# Código que calcule la integral por cada uno de los siguientes
# esquemas:
# - Regla del trapecio compuesta
# - Regla de Simpson1/3 compuesta
# - Regla de Simpson3/8 compuesta
# - Cuadratura de Gauss de 2 y 3 puntos
#
# Para las reglas compuestas use 𝑛 = 12 y 𝑛 = 15.
#
# **Nota: Teniendo presente que la guia no indica que se debe desarrollar ejercicio de metodologia simple solo se expondran ejercicios de tipo compuesto**
#
#
#
#
# ___
#
# #**Revisión teórica de las Integración numérica**
#
# **La Regla del trapecio compuesta**
#
#  Es un método numérico utilizado para aproximar la integral de una función en un intervalo dado. La idea principal es dividir el intervalo en varios subintervalos y aproximar el área bajo la curva en cada subintervalo como un trapecio. Luego, se suman todas las áreas de los trapecios para obtener una aproximación de la integral en el intervalo completo.
#
# La fórmula para la Regla del trapecio compuesta se ve así:
#
# $I\cong\frac{(b-a)}{2n}(f(x_0=a)+2\overset{n-1}{\underset{i=1}{\sum f(x_i)}}+f(x_n=b))$
#
# Donde $a$ y $b$ son los límites inferior y superior del intervalo,$n$ es el número de subintervalos y $ℎ$ es la longitud de cada subintervalo
#
# **La Regla de Simpson 1/3 compuesta**
#
# Es otro método numérico utilizado para aproximar la integral de una función. Al igual que la Regla del trapecio compuesta, divide el intervalo en subintervalos, pero aproxima el área bajo la curva en cada subintervalo utilizando una fórmula más precisa basada en una interpolación cuadrática.
#
# La fórmula para la Regla de Simpson 1/3 compuesta se expresa como:
#
# $I\cong\frac h3\left[f(x_0)+4\overset{n-1}{\underset{i=1,3,5...}{\sum f(x_i)}}+2\overset{n-2}{\underset{j=2,4,6,..}{\sum f(x_i)}}+f(x_j)+f(x_n)\right]$
#
# **La Regla de Simpson 3/8 compuesta**
#
# Es un método numérico utilizado para aproximar la integral de una función en un intervalo dado. Este método es una extensión de la Regla de Simpson 1/3 compuesta y proporciona una mayor precisión en la aproximación.
#
# La fórmula de la Regla de Simpson 3/8 compuesta es la siguiente:
#
# $I\cong\frac{3h}8\left[f(x_0)+3\overset n{\underset{i=0}{\sum f(x_{3i+1})}}+3\overset{\frac n3-1}{\underset{i=0}{\sum f(x_{3i+1})}}+2\overset{\frac n3-2}{\underset{i=0}{\sum f(x_{3i+1})}}+f(x_n)\right]$
#
# En esta fórmula, se divide el intervalo de integración en subintervalos de igual tamaño, donde 'n' es el número de subintervalos y 'h' es la longitud de cada subintervalo. Se evalúa la función en los extremos de cada subintervalo $(x_0, x_i, x_n)$ y se realiza la suma ponderada de estos valores utilizando los coeficientes adecuados $(3/8, 3/8, 2/8, 1/8)$para obtener una aproximación de la integral total.
#
#
# **La Cuadratura de Gauss**
# Es un método numérico utilizado para aproximar la integral de una función en un intervalo determinado. Este método se basa en una fórmula de integración que utiliza puntos y pesos específicos para obtener una aproximación precisa.
#
# En el caso de la Cuadratura de Gauss de 2 puntos, se seleccionan dos puntos dentro del intervalo de integración, y se asignan pesos específicos a cada punto. La fórmula de la Cuadratura de Gauss de 2 puntos es la siguiente:
#
# $I\cong\frac{(b-a)}2\left[w_1\ast f(\frac{(b+a)}2-\frac{(b-a)}2\sqrt{\frac13})+w_2\ast f(\frac{(b+a)}2+\frac{(b-a)}2\sqrt{\frac13})\right]$
#
# En esta fórmula, $a$ y $b$ representan los límites inferior y superior del intervalo de integración respectivamente. Los puntos $x_1$ y $x_2$ están dados por la fórmula mencionada, y los pesos $w_1$ y $w_2$ son asignados de manera específica para garantizar la precisión de la aproximación.
#
# Por otro lado, la Cuadratura de Gauss de 3 puntos sigue el mismo principio, pero en este caso se utilizan tres puntos y pesos correspondientes. La fórmula de la Cuadratura de Gauss de 3 puntos es la siguiente:
#
# $I\cong\frac{(b-a)}2\left[w_1\ast f(\frac{(b+a)}2-\frac{(b-a)}2\sqrt{\frac35})+w_2\ast f(\frac{(b+a)}2)+w_3\ast f(\frac{(b+a)}2+\frac{(b-a)}2\sqrt{\frac35})\right]$
# ___
#
# #**Referencias**
# Amador Moncada, J. A. (23 de 04 de 2021). UNAD Métodos Numéricos - Integración Numérica Parte 1. Obtenido de https://www.youtube.com/watch?v=XbZisO7rGF4
#
# Amador Moncada, J. A. (23 de 04 de 2021). UNAD Métodos Numéricos - Integración Numérica Parte 2. Obtenido de https://www.youtube.com/watch?v=sS-Dpc-B9rc
#
# Casteblanco, C. (15 de 04 de 2021). Concepto de derivada y diferenciación Numérica en Python - Métodos numéricos [100401] UNAD. Obtenido de https://youtu.be/-WIpCNWcAQA
#
# Nieves, A. (2015). Métodos numéricos: aplicados a la ingeniería. Grupo Editorial Patria. (pp. 627 – 632). https://elibro-net.bibliotecavirtual.unad.edu.co/es/ereader/unad/39455?page=644

# %%
import numpy as np
import math
from tabulate import tabulate
from prettytable import PrettyTable

𝑛_1 = 12 # intervalo asignado por el ejercici
n_2 = 15 # intervalo asignado por el ejercici
a=0
b= (np.pi/2)
I_Geogebra=0.9999999999987 #Valor calculado en Geogebra 
def f(x):         # Retorna cualquier funcion de F
  return  1/(1+np.sin(x))   # Funcion a Evaluar

# Verificador del error versus a constante calculada en Geogebra 
def errorIntegral(I_Geogebra,I):
  return ((abs(I_Geogebra-I))/I_Geogebra)*100


def trapecioCompuesto (a, b, n):
    h = (b - a) / n  # Ancho de cada subintervalo
    suma = f(a) + f(b)  # Suma de los valores en los extremos

    # Suma de los valores en los puntos interiores
    for i in range(1, n):
        suma += 2 * f(a + i * h)
    # Aplicar la fórmula final
    I = (h / 2) * suma
    return I




def simpsonUnTercioCompuesta(a, b, n):

     # Definición de parámetros
    
    h = (b - a) / n  # Tamaño de cada subintervalo

    # Evaluación de la función en los extremos del intervalo
    fx0 = f(a)  # Valor de la función en a
    fxn = f(b)  # Valor de la función en b

    # Inicialización de las sumatorias
    sumai = 0  # Sumatoria para los términos con índices impares
    sumap = 0  # Sumatoria para los términos con índices pares

    # Cálculo de las sumatorias
    for i in range(1, n, 2):
        sumai += f(a + i * h)  # Sumatoria para los términos con índices impares
    for i in range(2, n, 2):
        sumap += f(a + i * h)  # Sumatoria para los términos con índices pares

    # Cálculo de la aproximación de la integral utilizando la fórmula de Simpson 1/3 compuesta
    I = h / 3 * (f(a) + 4 * sumai + 2 * sumap + f(b))

    return I


def simpsonTresOctavosCompuesta(a, b, n):
    
    h = (b - a) / n  # Tamaño de cada subintervalo

    # Evaluación de la función en los extremos del intervalo
    fx0 = fx=(a)  # Valor de la función en a
    fxn = f(b)  # Valor de la función en b

    # Inicialización de las sumatorias
    suma1 = 0  # Primera sumatoria
    suma2 = 0  # Segunda sumatoria
    suma3 = 0  # Tercera sumatoria

    # Cálculo de las sumatorias
    for i in range(1, n, 3):
        suma1 += f(a + i * h)  # Primera sumatoria
    for i in range(2, n, 3):
        suma2 += f(a + i * h)  # Segunda sumatoria
    for i in range(3, n, 3):
        suma3 += f(a + i * h)  # Tercera sumatoria

    # Cálculo de la aproximación de la integral utilizando la fórmula de Simpson 3/8 compuesta
    I = 3 * h / 8 * (f(a) + 3 * suma1 + 3 * suma2 + 2 * suma3 + f(b))

    return I

def gaussDosPuntos(a, b):
    
    x1 = -0.5773502691896257  # coneficiente para x0
    x2 = 0.5773502691896257  #  coneficiente para x1

    # Transformación del intervalo [a, b] al intervalo [-1, 1]
    t1 = ((b - a) * x1 + (b + a)) / 2
    t2 = ((b - a) * x2 + (b + a)) / 2

    # Aplicación de la Cuadratura de Gauss de 2 puntos
    I = ((b - a) / 2) * (f(t1) + f(t2))
    return I

def gaussTresPuntos(a, b):
    #factores de argunmento y pesos de la formula de gauss
    x1 = -0.7745966692414834  # Raíz de 3/5
    x2 = 0
    x3 = 0.7745966692414834  # Raíz de 3/5
    c1=5/9 
    c2=8/9
    c3=5/9

    # Transformación del intervalo [a, b] al intervalo [-1, 1]
    t1 = ((b - a) * x1 + (b + a)) / 2
    t2 = ((b - a) * x2 + (b + a)) / 2
    t3 = ((b - a) * x3 + (b + a)) / 2

    # Aplicación de la Cuadratura de Gauss de 3 puntos
    I = ((b - a) / 2) * (c1 * f(t1) + c2 * f(t2) + c3 * f(t3))
    
    return I



#ini Cuadro con resultados por metodo numeros de intervalos y rango de error 
TPrimeraF = PrettyTable(["Metodo","n","Integral aprox","Error(%)"])
TPrimeraF.add_row(["Trapecio Compuesto ",n_1,trapecioCompuesto (a, b, n_1),errorIntegral(I_Geogebra,trapecioCompuesto (a, b, n_1))])
TPrimeraF.add_row(["Trapecio Compuesto ",n_2,trapecioCompuesto (a, b, n_2),errorIntegral(I_Geogebra,trapecioCompuesto (a, b, n_2))])
TPrimeraF.add_row(["Simpson 1/3 Compuesta ",n_1,simpsonUnTercioCompuesta (a, b, n_1),errorIntegral(I_Geogebra,simpsonUnTercioCompuesta (a, b, n_1))])
TPrimeraF.add_row(["Simpson 1/3 Compuesta ",n_2,simpsonUnTercioCompuesta (a, b, n_2),errorIntegral(I_Geogebra,simpsonUnTercioCompuesta (a, b, n_2))])
TPrimeraF.add_row(["Simpson 3/8 Compuesta ",n_1,simpsonTresOctavosCompuesta (a, b, n_1),errorIntegral(I_Geogebra,simpsonTresOctavosCompuesta (a, b, n_1))])
TPrimeraF.add_row(["Simpson 3/8 Compuesta ",n_2,simpsonTresOctavosCompuesta (a, b, n_2),errorIntegral(I_Geogebra,simpsonTresOctavosCompuesta (a, b, n_2))])
TPrimeraF.add_row(["Gauss Dos Puntos ","2 Puntos",gaussDosPuntos(a, b),errorIntegral(I_Geogebra,gaussDosPuntos(a, b))])
TPrimeraF.add_row(["Gauss Tres Puntos ","3 Puntos",gaussTresPuntos(a, b),errorIntegral(I_Geogebra,gaussTresPuntos(a, b))])


print(TPrimeraF)
# fin Cuadro 

# verificacion de minimo error para analisis
min_value = min(errorIntegral(I_Geogebra,trapecioCompuesto (a, b, n_1)),
                errorIntegral(I_Geogebra,trapecioCompuesto (a, b, n_2)),
                errorIntegral(I_Geogebra,simpsonUnTercioCompuesta (a, b, n_1)),
                errorIntegral(I_Geogebra,simpsonUnTercioCompuesta (a, b, n_2)),
                errorIntegral(I_Geogebra,simpsonTresOctavosCompuesta (a, b, n_1)),
                errorIntegral(I_Geogebra,simpsonTresOctavosCompuesta (a, b, n_2)),
                errorIntegral(I_Geogebra,gaussDosPuntos(a, b)),
                errorIntegral(I_Geogebra,gaussTresPuntos(a, b))
                )
#Organizacion minimo
sorted_values = sorted([
                errorIntegral(I_Geogebra,trapecioCompuesto (a, b, n_1)),
                errorIntegral(I_Geogebra,trapecioCompuesto (a, b, n_2)),
                errorIntegral(I_Geogebra,simpsonUnTercioCompuesta (a, b, n_1)),
                errorIntegral(I_Geogebra,simpsonUnTercioCompuesta (a, b, n_2)),
                errorIntegral(I_Geogebra,simpsonTresOctavosCompuesta (a, b, n_1)),
                errorIntegral(I_Geogebra,simpsonTresOctavosCompuesta (a, b, n_2)),
                errorIntegral(I_Geogebra,gaussDosPuntos(a, b)),
                errorIntegral(I_Geogebra,gaussTresPuntos(a, b))                
                ])
#El numero de veces que es mas grande del error  
diff = sorted_values[-1] / sorted_values[0]
 
print("El valor mínimo es:", min_value)
print("La Cantidad de veces que es mas grande el error encontrado es:", diff)
# Out:
# +------------------------+----------+--------------------+-----------------------+
# |         Metodo         |    n     |   Integral aprox   |        Error(%)       |
# +------------------------+----------+--------------------+-----------------------+
# |  Trapecio Compuesto    |    12    | 1.0014258653243397 |  0.14258653256415615  |
# |  Trapecio Compuesto    |    15    | 1.0009130197772473 |  0.09130197785484839  |
# | Simpson 1/3 Compuesta  |    12    | 1.0000079603721694 | 0.0007960373469405946 |
# | Simpson 1/3 Compuesta  |    15    | 0.9825499961164242 |   1.7450003882298484  |
# | Simpson 3/8 Compuesta  |    12    | 1.0000175078457472 |  0.001750784704714958 |
# | Simpson 3/8 Compuesta  |    15    | 1.0000072891802976 | 0.0007289181597545697 |
# |   Gauss Dos Puntos     | 2 Puntos | 0.9960761538629542 |   0.3923846135750913  |
# |   Gauss Tres Puntos    | 3 Puntos | 0.9998373158354098 |  0.016268416329045018 |
# ...

# %% [markdown]
# **Integral calculada en Geogebra**
# ![integral.png](data:image/png;base64,...)

# %% [markdown]
# **Analisis de Resultados Metodos de Integracion**
#
# La integración de los distintos modelos en las mismas condiciones permite obtener la perspectiva del la aproximación para obtener el área bajo los intervalos propuestos del ejercicio a la curva formada por la función, por lo tanto, podemos apreciar que todos los modelos son muy buenos en términos generales si solo habláramos de áreas no tan específicas, ahora si entramos en detalle el método tradicional de integración es el más preciso, pero si se tratara de una función muy extensa o difícil de desarrollar, el método mas eficiente cercano a obtener un resultado muy útil seria del Simpson 3/8 Compuesta, ya que de los método fue el que alcanzo a acercarse de tal manera que su diferencia puede llegar a ser despreciable, ya que en el cuadro podemos apreciar que el método menos eficiente es el de tres puntos ya que su error supera al anterior por mas de 2000 veces su tamaño

# %% [markdown]
# # Conclusión
# Una vez estudiados los métodos numéricos para encontrar la integral o el área bajo la curva de dos puntos he podido comprender que estos métodos numéricos son muy similares en esencia a el procedimiento analítico sin embargo tiene la ventaja de simplificar el procesamiento del calculo matemático dado a que por medio de procedimientos simples logra acercarse al mismo valor que podríamos encontrar por analítico, sin embargo debemos tener presente este puede dejar vacíos de valor en los cálculos lo cual significa que dependemos de la necesidad de precisión para usar uno u otro.
